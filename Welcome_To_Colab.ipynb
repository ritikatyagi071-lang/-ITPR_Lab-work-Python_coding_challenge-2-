# %% [markdown]
# <a href="https://colab.research.google.com/github/ritikatyagi071-lang/-ITPR_Lab-work-Python_coding_challenge-2-/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Python program to find age category
age = int(input())
if age < 18:
    print("Minor")
elif age < 60:
    print("Adult")
else:
    print("Senior")
# Out:
# 65
# Senior
